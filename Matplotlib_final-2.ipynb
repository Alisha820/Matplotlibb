# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# We will be using the churn data for this week's project

# %%
churn = pd.read_csv('churn.csv')
churn
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
churn.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# Lets drop some columns so we have a specific data to make graphs from.

# %%
dchurn = churn.drop(columns = ['MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies'], axis=1)
dchurn
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService        Contract PaperlessBilling              PaymentMethod  \
# 0              No  Month-to-month              Yes           Electronic check
# ...

# %% [markdown]
# **Bar Chart**

# %%
ax = sns.catplot(y='Churn', kind='count', data=dchurn, height=2.6, aspect=2.5)

# %%
plt.figure(figsize=(9, 4.5))
barplot_percentages("PaymentMethod", orient='h')

# %% [markdown]
# **Scattered Plot**

# %%
g = sns.FacetGrid(dchurn, row='SeniorCitizen', col='gender', hue='Churn', height=3.5)
g.map(plt.scatter, 'tenure', 'MonthlyCharges', alpha=0.6)
g.add_legend();

# %% [markdown]
# **Bar Chart**

# %%
fig,axis = plt.subplots(1,2,figsize=(12,4))
axis[0].set_title('Has partner')
axis[1].set_title('Has dependents')
axis_y = 'Percentage of customers'

#plot Partner column
gp_partner = dchurn.groupby('Partner')['Churn'].value_counts()/len(dchurn)
gp_partner = gp_partner.to_frame().rename({"Churn":axis_y}, axis=1).reset_index()
ax = sns.barplot(x='Partner', y=axis_y, hue='Churn', data=gp_partner, ax=axis[0])


#plot Dependents column
gp_dependent = dchurn.groupby('Dependents')['Churn'].value_counts()/len(dchurn)
gp_dependent = gp_dependent.to_frame().rename({"Churn":axis_y}, axis=1).reset_index()
ax = sns.barplot(x='Dependents', y=axis_y, hue='Churn', data=gp_dependent, ax=axis[1])
